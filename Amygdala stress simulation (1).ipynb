# %%
# Initial values
PFC = 100
Amygdala = 100
Hippocampus = 100

# Apply 5 cycles of stress to Amygdala
for cycle in range(1, 6):
    Amygdala -= 15
    print(f"Cycle {cycle} - Amygdala: {Amygdala}")

    if Amygdala < 40:
        print("⚠️ Motif at risk! Compensation needed.")
        break
# Out:
# Cycle 1 - Amygdala: 85
# Cycle 2 - Amygdala: 70
# Cycle 3 - Amygdala: 55
# Cycle 4 - Amygdala: 40
# Cycle 5 - Amygdala: 25
# ⚠️ Motif at risk! Compensation needed.

# %% [markdown]
# This simulation models the signal decay of a single brain region — the Amygdala — under repeated stress. Starting with a signal strength of 100, the region is exposed to stress over a series of cycles, losing 15 units of signal strength per cycle. Once the signal drops below 40, the system identifies it as structurally at risk and outputs a warning. The simulation uses a simple for loop and conditional if statement to demonstrate threshold-based failure in a localized node. This forms the foundational logic for more complex models of stress propagation and motif-level compensation in neural networks.
