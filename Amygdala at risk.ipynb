# %%
# Initial values
PFC = 100
Amygdala = 100
Hippocampus = 100

# Apply 5 cycles of stress to Amygdala
for cycle in range(1, 6):
    Amygdala -= 15
    print(f"Cycle {cycle} - Amygdala: {Amygdala}")

    if Amygdala < 40:
        print("⚠️ Motif at risk! Compensation needed.")
        break
# Out:
# Cycle 1 - Amygdala: 85
# Cycle 2 - Amygdala: 70
# Cycle 3 - Amygdala: 55
# Cycle 4 - Amygdala: 40
# Cycle 5 - Amygdala: 25
# ⚠️ Motif at risk! Compensation needed.

# %% [markdown]
# This simulation shows how repeated stress on one node (Amygdala) causes signal loss. If signal drops below 40%, the motif is considered structurally at risk and flagged for compensation.
